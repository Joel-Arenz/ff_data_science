# %%
import nfl_data_py as nfl

# %%
df_weekly = nfl.import_weekly_data(years=[2022])
# Out:
# Downcasting floats.

# %%
df_weekly.head()
# Out:
#     player_id player_name player_display_name position position_group  \
# 0  00-0019596     T.Brady           Tom Brady       QB             QB
# 1  00-0019596     T.Brady           Tom Brady       QB             QB
# 2  00-0019596     T.Brady           Tom Brady       QB             QB
# 3  00-0019596     T.Brady           Tom Brady       QB             QB
# 4  00-0019596     T.Brady           Tom Brady       QB             QB
#
#                                         headshot_url recent_team  season  \
# 0  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 1  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 2  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 3  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 4  https://static.www.nfl.com/image/private/f_aut...          TB    2022
#
#    week season_type  ... receiving_first_downs  receiving_epa  \
# ...

# %%
df_weekly.shape
# Out:
# (5631, 53)

# %%
df_weekly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5631 entries, 0 to 5630
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   player_id                    5631 non-null   object
#  1   player_name                  5631 non-null   object
#  2   player_display_name          5631 non-null   object
#  3   position                     5631 non-null   object
#  4   position_group               5631 non-null   object
#  5   headshot_url                 5631 non-null   object
#  6   recent_team                  5631 non-null   object
#  7   season                       5631 non-null   int32
#  8   week                         5631 non-null   int32
#  9   season_type                  5631 non-null   object
#  10  opponent_team                5631 non-null   object
#  11  completions                  5631 non-null   int32
#  12  attempts                     5631 non-null   int32
# ...

# %%
df_weekly.isnull().sum()
# Out:
# player_id                         0
# player_name                       0
# player_display_name               0
# position                          0
# position_group                    0
# headshot_url                      0
# recent_team                       0
# season                            0
# week                              0
# season_type                       0
# opponent_team                     0
# completions                       0
# attempts                          0
# passing_yards                     0
# passing_tds                       0
# interceptions                     0
# sacks                             0
# sack_yards                        0
# sack_fumbles                      0
# sack_fumbles_lost                 0
# passing_air_yards                 0
# passing_yards_after_catch         0
# passing_first_downs               0
# passing_epa                    4938
# passing_2pt_conversions           0
# pacr                           4946
# ...

# %%
df_weekly.describe()
# Out:
#        season         week  completions     attempts  passing_yards  \
# count  5631.0  5631.000000  5631.000000  5631.000000    5631.000000
# mean   2022.0     9.937666     2.166400     3.375244      23.684425
# std       0.0     5.588639     6.637119    10.235175      73.065651
# min    2022.0     1.000000     0.000000     0.000000      -3.000000
# 25%    2022.0     5.000000     0.000000     0.000000       0.000000
# 50%    2022.0    10.000000     0.000000     0.000000       0.000000
# 75%    2022.0    15.000000     0.000000     0.000000       0.000000
# max    2022.0    22.000000    43.000000    68.000000     481.000000
#
#        passing_tds  interceptions        sacks   sack_yards  sack_fumbles  \
# count  5631.000000    5631.000000  5631.000000  5631.000000   5631.000000
# mean      0.141005       0.077429     0.240810     1.586752      0.032499
# std       0.537748       0.357175     0.887996     6.019763      0.208629
# ...

# %%
df_weekly.value_counts()
# Out:
# player_id   player_name  player_display_name  position  position_group  headshot_url                                                                        recent_team  season  week  season_type  opponent_team  completions  attempts  passing_yards  passing_tds  interceptions  sacks  sack_yards  sack_fumbles  sack_fumbles_lost  passing_air_yards  passing_yards_after_catch  passing_first_downs  passing_epa  passing_2pt_conversions  pacr      dakota     carries  rushing_yards  rushing_tds  rushing_fumbles  rushing_fumbles_lost  rushing_first_downs  rushing_epa  rushing_2pt_conversions  receptions  targets  receiving_yards  receiving_tds  receiving_fumbles  receiving_fumbles_lost  receiving_air_yards  receiving_yards_after_catch  receiving_first_downs  receiving_epa  receiving_2pt_conversions  racr  target_share  air_yards_share  wopr      special_teams_tds  fantasy_points  fantasy_points_ppr
# ...

# %%
df_qb = df_weekly[df_weekly['position'] == 'QB']
df_wr = df_weekly[df_weekly['position'] == 'WR']

# %%
df_qb = df_qb.drop(columns=['player_display_name', 'season_type', 'headshot_url'])

# %%
df_qb.describe()
# Out:
#        season        week  completions    attempts  passing_yards  \
# count   677.0  677.000000   677.000000  677.000000     677.000000
# mean   2022.0   10.146233    17.994092   28.029542     196.757751
# std       0.0    5.610710     9.037559   13.435217     101.779861
# min    2022.0    1.000000     0.000000    0.000000      -3.000000
# 25%    2022.0    5.000000    13.000000   21.000000     139.000000
# 50%    2022.0   10.000000    19.000000   30.000000     210.000000
# 75%    2022.0   15.000000    24.000000   37.000000     264.000000
# max    2022.0   22.000000    43.000000   68.000000     481.000000
#
#        passing_tds  interceptions       sacks  sack_yards  sack_fumbles  ...  \
# count   677.000000     677.000000  677.000000  677.000000    677.000000  ...
# mean      1.166913       0.638109    1.992615   13.116692      0.267356  ...
# std       1.097428       0.835897    1.750301   12.235835      0.544755  ...
# ...

# %%
df_wr.info()
columns_all_player = ['player_id', 'player_name', 'position', 'recent_team', 'season', '']
wr_columns = []
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2238 entries, 59 to 5630
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   player_id                    2238 non-null   object
#  1   player_name                  2238 non-null   object
#  2   player_display_name          2238 non-null   object
#  3   position                     2238 non-null   object
#  4   position_group               2238 non-null   object
#  5   headshot_url                 2238 non-null   object
#  6   recent_team                  2238 non-null   object
#  7   season                       2238 non-null   int32
#  8   week                         2238 non-null   int32
#  9   season_type                  2238 non-null   object
#  10  opponent_team                2238 non-null   object
#  11  completions                  2238 non-null   int32
#  12  attempts                     2238 non-null   int32
# ...

# %%
df_seasonal = nfl.import_seasonal_data([2022])

# %%
df_seasonal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 619 entries, 0 to 618
# Data columns (total 58 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   player_id                    619 non-null    object
#  1   season                       619 non-null    int64
#  2   season_type                  619 non-null    object
#  3   completions                  619 non-null    int32
#  4   attempts                     619 non-null    int32
#  5   passing_yards                619 non-null    float64
#  6   passing_tds                  619 non-null    int32
#  7   interceptions                619 non-null    float64
#  8   sacks                        619 non-null    float64
#  9   sack_yards                   619 non-null    float64
#  10  sack_fumbles                 619 non-null    int32
#  11  sack_fumbles_lost            619 non-null    int32
#  12  passing_air_yards            619 non-null    float64
# ...
